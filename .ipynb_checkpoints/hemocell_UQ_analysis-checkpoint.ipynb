# %% [markdown]
# # Hemocell One Cell Shear Simulation UQ Analysis

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from local_config import *

# %% [markdown]
# ## Read data and results

# %%
sample_df = pd.read_csv("hemocell_samples.csv",sep=";")
qoi = np.load("hemocell_qoi.npy")

data = pd.read_csv("%s/Ekcta_100.csv" % (datapath),sep=";")
data = data.loc[data["Treatment"] == 0.5]
stress,el,el_err = data.values[:2,[1,3,4]].T

# %%
print(el)
print(qoi)
print(sample_df)
# Out:
# [0.119 0.05 ]
# [[0.02484862 0.03415562]
#  [0.02130153 0.02963332]
#  [0.02140471 0.02994692]
#  [0.02506492 0.03446192]
#  [0.02639904 0.03559786]
#  [0.02639904 0.03559786]
#  [0.0219154  0.030633  ]
#  [0.02196029 0.03069366]
#  [0.02128765 0.0296814 ]
#  [0.02029866 0.02868577]]
#    Unnamed: 0      kLink      kBend  model_uncertainty  likelihood
# 0           0  11.959425  56.456027           0.963090   19.380301
# 1           1  45.614975  60.659648           0.961229   18.280589
# 2           2  43.078093  60.690765           0.950773   18.564623
# 3           3   9.724860  72.040036           0.816514   23.270519
# 4           4   1.380136  68.728410           0.816730   23.805272
# 5           5   1.380136  68.728410           0.816730   23.805272
# 6           6  37.484977  86.552879           0.672470   24.077494
# 7           7  37.598749  90.481095           0.662739   24.200788
# 8           8  44.964792  92.285034           0.642868   23.601888
# 9           9  56.924361  93.603592           0.697762   22.540028

# %%
plt.figure(figsize=(20,10))
plt.grid(True)

# Data
plt.errorbar(stress,el,yerr=el_err,label="Data")

# Highest likelihood
mle = np.argmax(sample_df["likelihood"].values)
plt.plot(stress,qoi[mle],label="Max Likelihood Sample")

# Mean QoI output
mean = np.mean(qoi,axis=0)
var = np.sum((qoi - mean[None,:])**2,axis=0) / (qoi.shape[0] - 1)
conf = 1.96 * np.sqrt(var / qoi.shape[0])

plt.errorbar(stress,mean,yerr=conf,label="Mean QoI")

plt.legend()

plt.show()
