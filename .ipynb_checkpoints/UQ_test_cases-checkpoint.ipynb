# %% [markdown]
# # Uncertainty Quantification for test cases

# %%
import os
import shutil

import numpy as np
from scipy.stats import norm,uniform,multivariate_normal

import UQLib.calibration.TMCMC as TMCMC
import test_cases.sinusoidal as sinusoidal
import test_cases.cosine as cosine

import matplotlib.pyplot as plt

np.random.seed(1234)

# %% [markdown]
# ## Inverse UQ for a cosine function

# %%
modelpath = "/home/kevin/master_project/IUQ-Project/test_cases/cosine.py"

# Generate data with Gaussian noise
x, y, y_err, true_params = cosine.generate(10,scale=0.01)

model_params = ["a","c","k","f"]

print("True parameter values:")
print(tuple(model_params), "=")
print(tuple(true_params))

error_params = ["s"]
design_vars = ["x"]

model_errors = ["s" for n in range(x.shape[0])]

# Define uniform prior wrapper functions and samplers for the model parameters
model_func = lambda val: uniform.pdf(val,-2.0,4.0)
model_sampler = lambda n_samples: np.random.uniform(-2.0,2.0,size=n_samples)

# Define prior wrapper function and sampler for the error parameter
error_func = lambda val: uniform.pdf(val,0.01,0.99)
error_sampler = lambda n_samples: np.random.uniform(0.01,1.0,size=n_samples)

model_priors = [(model_func,model_sampler) for param in model_params]
error_priors = [(error_func,error_sampler)]

# Construct problem dict
problem = {"setup":cosine.setup,
           "measure":cosine.read_output,
           "modelpath":modelpath,
           "model parameters":model_params,
           "error parameters":error_params,
           "design variables":design_vars,
           "input data":x,
           "output data":y,
           "data errors":y_err,
           "error mapping":model_errors,
           "model priors":model_priors,
           "error priors":error_priors
          }

os.makedirs("TMCMC_output")
os.chdir("TMCMC_output")

df = TMCMC.sample(problem,10,nprocs=8)

os.chdir("..")

# Remove garbage
shutil.rmtree("./TMCMC_output")

print(df)
# Out:
# True parameter values:
# ('a', 'c', 'k', 'f') =
# (-3.084805496211077, 1.2210877103983186, -0.6227226099288554, 2.8535858371376923)
# Calculate next p
# p: 0.030213943041171733
# COV: 0.9999996349974423
# Running stage 1...
# Current max likelihood: 7.723393431647431e-10
# Calculate next p
# p: 0.174824745544469
# COV: 0.9999999810627569
# Running stage 2...
# Current max likelihood: 5.240211887761791e-09
# Calculate next p
# p: 0.36223824980523256
# COV: 0.999999958945045
# Running stage 3...
# Current max likelihood: 5.329111006368528e-09
# Calculate next p
# p: 1.0
# COV: 0.7785565676604047
# Running stage 4...
# Current max likelihood: 5.189621320877663e-09
#           a         c         k         f         s    likelihood
# 0  0.420272 -0.295680 -0.523476 -1.096627  0.786407  5.138549e-09
# 1  0.408883 -0.298124 -0.546602 -1.139488  0.784208  5.093252e-09
# 2  0.398585 -0.290646 -0.508714 -1.130217  0.788934  5.189621e-09
# 3  0.413930 -0.282485 -0.492990 -1.078944  0.785995  5.130119e-09
# 4  0.442390 -0.282049 -0.483718 -1.029841  0.783363  5.075634e-09
# 5  0.502349 -0.331405 -0.650119 -1.066068  0.768322  3.318088e-09
# 6  0.456225 -0.319483 -0.628104 -1.052596  0.773325  3.361025e-09
# 7  0.466915 -0.317924 -0.625674 -1.035367  0.771753  3.332363e-09
# 8  0.405622 -0.275359 -0.488292 -0.949328  0.786981  4.903915e-09
# 9  0.341231 -0.335249 -0.769207 -1.472407  0.767752  8.613095e-10

# %% [markdown]
# ## Propagate uncertainty forward to output

# %%
a,c,k,f = true_params

plt.figure(figsize=(20,10))
plt.grid(True)

# Data
plt.errorbar(x,y,yerr=y_err,label="Data")

# True data
#plt.plot(x,cosine.evaluate(x,a,c,k,f),label="True distribution")

# Highest likelihood
mle = np.argmax(df["likelihood"].values)
a,c,k,f = df.values[mle,:4]
#plt.plot(x,cosine.evaluate(x,a,c,k,f),label="Max Likelihood Sample")

# Mean QoI output
samples = df.values[:,:4]
qoi = np.empty((samples.shape[0],x.shape[0]))
for i in range(qoi.shape[0]):
    a,c,k,f = df.values[i,:4]
    qoi[i] = cosine.evaluate(x,a,c,k,f)
    
mean = np.mean(qoi,axis=0)
var = np.sum((qoi - mean[None,:])**2,axis=0) / (qoi.shape[0] - 1)
conf = 1.96 * np.sqrt(var / qoi.shape[0])

plt.errorbar(x,mean,yerr=conf,label="Mean QoI")

plt.legend()

plt.show()
