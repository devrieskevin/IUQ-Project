# %% [markdown]
# # Uncertainty Quantification for test cases

# %%
import os
import shutil

import dill

import numpy as np
from scipy.stats import norm,uniform,multivariate_normal

import UQLib.calibration.TMCMC as TMCMC
import UQLib.calibration.ABCSubSim as ABCSubSim
import test_cases.sinusoidal as sinusoidal
import test_cases.cosine as cosine

import matplotlib.pyplot as plt

seed = 1234
n_samples = 1000
modelpath = "/home/kevin/master_project/remote_lisa/IUQ-Project/test_cases/cosine.py"
logpath = "/home/kevin/master_project/remote_lisa/IUQ-Project/test_log.pkl"

# %% [markdown]
# # Inverse UQ for a cosine function
#
# ## Exact Posterior sampling using the TMCMC algorithm

# %%
np.random.seed(seed)

# Generate data with Gaussian noise
x, y, y_err, true_params = cosine.generate(15,scale=0.01)
a, c, k, f = true_params

# Parameter names
model_params = ["a","c","k","f"]
error_params = ["error_boyz"]
design_vars = ["x"]

print("True parameter values:")
print(tuple(model_params), "=")
print((a,c,k,f))

# Design variable values
#design_vals = np.row_stack(np.broadcast(x,a,c))
design_vals = x

# Error parameter per design point
model_errors = ["error_boyz" for n in range(x.shape[0])]

# Define uniform prior wrapper functions and samplers for the model parameters
model_prior = lambda sample: np.prod([uniform.pdf(sample[n],-5.0,10.0) for n in range(len(model_params))])
model_sampler = lambda n_samples: np.random.uniform(-5.0,5.0,size=(n_samples,len(model_params)))

# Define prior wrapper function and sampler for the error parameter
error_prior = lambda sample: np.prod([uniform.pdf(sample[n],0.001,0.999) for n in range(len(error_params))])
error_sampler = lambda n_samples: np.random.uniform(0.001,1.0,size=(n_samples,len(error_params)))

# Construct problem dict
problem_ext = {"model_type":"external",
               "setup":(lambda params: cosine.setup(modelpath,params)),
               "measure":cosine.read_output,
               "model_params":model_params,
               "error_params":error_params,
               "design_vars":design_vars,
               "input_data":design_vals,
               "output_data":y,
               "data_errors":y_err,
               "error_mapping":model_errors,
               "model_prior":model_prior,
               "model_sampler":model_sampler,
               "error_prior":error_prior,
               "error_sampler":error_sampler
              }

problem_py = {"model_type":"python",
              "evaluate":cosine.evaluate_dict,
              "model_params":model_params,
              "error_params":error_params,
              "design_vars":design_vars,
              "input_data":design_vals,
              "output_data":y,
              "data_errors":y_err,
              "error_mapping":model_errors,
              "model_prior":model_prior,
              "model_sampler":model_sampler,
              "error_prior":error_prior,
              "error_sampler":error_sampler
              }


try:
    shutil.rmtree("./TMCMC_output")
except FileNotFoundError:
    pass

os.makedirs("TMCMC_output")
os.chdir("TMCMC_output")

#TMCMC_sampler = TMCMC.load_state(logpath)
#df,qoi = TMCMC_sampler.sample(n_samples,checkpoint=True)

TMCMC_sampler = TMCMC.TMCMC(problem_py,logstep=2000,logpath=logpath,nprocs=8)
df,qoi = TMCMC_sampler.sample(n_samples)

os.chdir("..")

# Remove garbage
shutil.rmtree("./TMCMC_output")

print(df)
# Out:
# True parameter values:
# ('a', 'c', 'k', 'f') =
# (-3.084805496211077, 1.2210877103983186, -0.6227226099288554, 2.8535858371376923)
# Initializing...
# Current max likelihood: 3.135016229224065e-13
# Calculating p for stage 1...
# p: 1e-06
# COV: 1.400280127168606
# Running stage 1...
# Current max likelihood: 2.780611447018255e-11
# Calculating p for stage 2...
# p: 0.006063629301568146
# COV: 0.9999966519195543
# Running stage 2...
# Current max likelihood: 2.3060364530458027e-10
# Calculating p for stage 3...
# p: 0.03164428476484175
# COV: 0.9999903636332583
# Running stage 3...
# Current max likelihood: 2.3060364530458027e-10
# Calculating p for stage 4...
# p: 0.07199574105455489
# COV: 0.9999994313412084
# Running stage 4...
# Current max likelihood: 2.3060364530458027e-10
# Calculating p for stage 5...
# p: 0.16796539912153366
# COV: 1.0000025398088292
# Running stage 5...
# Current max likelihood: 2.3060364530458027e-10
# Calculating p for stage 6...
# p: 0.3187643488056436
# COV: 1.00000089467072
# Running stage 6...
# Current max likelihood: 1.2600989693851864e-09
# Calculating p for stage 7...
# p: 0.6168464292811259
# COV: 0.9999998624662862
# Running stage 7...
# Current max likelihood: 1.2750580147448387e-09
# Calculating p for stage 8...
# p: 1.0
# COV: 0.4894866579696854
# Running stage 8...
# Current max likelihood: 1.5412920406796746e-09
#            a         c         k         f  error_boyz    likelihood
# 0  -1.263987 -0.000663  0.636705  3.865033    0.721032  2.905781e-10
# 1  -1.192879 -0.049258  0.586915  3.783400    0.729083  2.814243e-10
# 2  -1.287488  0.030160  0.660407  3.867231    0.720560  5.697792e-11
# 3  -1.278112  0.013443  0.619121  3.829082    0.725287  4.980636e-10
# 4  -1.278112  0.013443  0.619121  3.829082    0.725287  4.980636e-10
# 5  -1.231297  0.027740  0.638398  3.843931    0.726728  2.274661e-10
# 6  -1.460719 -0.055729  0.566325  3.798646    0.718275  1.254474e-10
# 7  -1.460719 -0.055729  0.566325  3.798646    0.718275  1.254474e-10
# 8  -1.436006 -0.057273  0.581374  3.725728    0.714288  7.326243e-10
# 9  -1.268573  0.005256  0.544123  3.510547    0.737648  1.224118e-10
# 10 -1.239774  0.020494  0.582834  3.619834    0.733294  8.383224e-11
# 11 -1.451776  0.028627  0.564865  3.586893    0.716279  5.413200e-10
# 12 -1.421610  0.009818  0.583496  3.668197    0.718969  5.186167e-10
# 13 -1.436227  0.020762  0.582220  3.653719    0.721925  5.132548e-10
# 14 -1.533000 -0.030413  0.533763  3.629455    0.709490  4.272114e-10
# 15 -1.533000 -0.030413  0.533763  3.629455    0.709490  4.272114e-10
# 16 -1.453051  0.122535  0.606418  3.742250    0.706039  1.450012e-09
# 17 -1.468285  0.143445  0.631631  3.762824    0.706599  1.277435e-09
# 18 -1.464288  0.188605  0.621920  3.702921    0.705633  1.394300e-09
# 19 -1.467838  0.188048  0.644604  3.736914    0.704171  4.285336e-10
# 20 -1.307858 -0.050392  0.552049  3.602997    0.731830  2.397987e-10
# 21 -1.318086 -0.038000  0.553602  3.597774    0.732382  2.504436e-10
# 22 -1.292902 -0.056449  0.553761  3.593693    0.734217  1.395481e-10
# 23 -1.282622 -0.045071  0.533508  3.546183    0.735982  2.352752e-10
# 24 -1.291833  0.008799  0.630864  3.822020    0.722580  2.306036e-10
# 25 -1.358322  0.021295  0.611069  3.818711    0.718717  8.133999e-10
# 26 -1.328530  0.064928  0.616386  3.821874    0.714438  7.380220e-10
# 27 -1.281702  0.084751  0.625694  3.825441    0.716370  6.572300e-10
# 28 -1.296712  0.113731  0.601870  3.741201    0.716601  5.716967e-10
# 29 -1.334300  0.093417  0.597462  3.780555    0.714411  3.250062e-10
# ..       ...       ...       ...       ...         ...           ...
# 70 -1.515603 -0.007002  0.698359  4.069422    0.697310  6.110361e-10
# 71 -1.537118  0.013350  0.713448  4.090197    0.692159  3.014176e-10
# 72 -1.537118  0.013350  0.713448  4.090197    0.692159  3.014176e-10
# 73 -1.447341 -0.013920  0.719429  4.149928    0.701206  4.626727e-10
# 74 -1.444248 -0.017962  0.712170  4.147346    0.699561  8.444640e-10
# 75 -1.444248 -0.017962  0.712170  4.147346    0.699561  8.444640e-10
# 76 -1.521522  0.016288  0.700900  4.072419    0.699806  8.761246e-10
# 77 -1.249573  0.045704  0.638218  3.822454    0.734569  2.058605e-10
# 78 -1.257165  0.019796  0.625800  3.818990    0.738689  2.922115e-10
# 79 -1.291833  0.008799  0.630864  3.822020    0.722580  2.306036e-10
# 80 -1.291833  0.008799  0.630864  3.822020    0.722580  2.306036e-10
# 81 -1.274565  0.009357  0.615025  3.811746    0.725922  4.542520e-10
# 82 -1.274565  0.009357  0.615025  3.811746    0.725922  4.542520e-10
# 83 -1.264581  0.022098  0.625419  3.838996    0.725487  4.564250e-10
# 84 -1.208578  0.002300  0.571886  3.706223    0.727463  3.038611e-10
# 85 -1.227449 -0.018410  0.578798  3.741771    0.728360  3.381049e-10
# 86 -1.194053  0.038656  0.590046  3.781764    0.714177  2.386644e-10
# 87 -1.199517  0.048944  0.588058  3.765541    0.719101  2.395571e-10
# 88 -1.405845 -0.100772  0.554348  3.734598    0.717224  4.826133e-10
# 89 -1.410205 -0.149417  0.548195  3.746609    0.702392  4.881985e-10
# 90 -1.398190 -0.126165  0.551082  3.717533    0.704561  6.370586e-10
# 91 -1.408331 -0.148606  0.584928  3.846182    0.699453  8.025723e-10
# 92 -1.281734  0.025184  0.629029  3.799986    0.718893  2.127861e-10
# 93 -1.308700  0.023245  0.628058  3.783170    0.718001  1.505962e-10
# 94 -1.333800 -0.032423  0.602166  3.758660    0.721286  2.982053e-10
# 95 -1.367052 -0.046383  0.583178  3.735215    0.719164  5.908191e-10
# 96 -1.076618 -0.003130  0.766127  4.554872    0.697980  1.568975e-11
# 97 -0.749471  0.117549  0.817521  4.437064    0.745304  3.036843e-11
# 98 -0.773642  0.131833  0.778624  4.216813    0.740839  2.278520e-11
# 99 -1.664646 -0.747261  0.607276  4.203678    0.816838  4.716713e-11
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Propagate uncertainty forward to output

# %%
a,c,k,f = true_params

plt.figure(figsize=(20,10))
plt.grid(True)

# Data
plt.errorbar(x,y,yerr=y_err,label="Data")

# True values
interval = np.linspace(0,2*np.pi,1000)
y_true, _ = cosine.evaluate(interval,a,c,k,f)
#plt.plot(interval,y_true,label="True distribution")

# Highest likelihood
mle = np.argmax(df["likelihood"].values)
plt.plot(x,qoi[mle],label="Max Likelihood Sample")

# All distributions
#for n in range(qoi.shape[0]):
#    plt.plot(x,qoi[n])

# Mean QoI output
mean = np.mean(qoi,axis=0)
var = np.sum((qoi - mean[None,:])**2,axis=0) / (qoi.shape[0] - 1)
conf = 1.96 * np.sqrt(var / qoi.shape[0])

plt.errorbar(x,mean,yerr=conf,label="Mean QoI")

plt.legend()

plt.show()

# %% [markdown]
# ### Sanity check for output parity

# %%
for n in range(qoi.shape[0]):
    a,c,k,f = df.values[n,:4]
    remeasure_qoi,_ = cosine.evaluate(x,a,c,k,f)
    if (qoi[n] != remeasure_qoi).any():
        print("Difference:",qoi[n]-remeasure_qoi[n])

# %% [markdown]
# ## Approximate Bayesian Computation (ABC) using Subset Simulation

# %%
def distance(a,b):
    return np.sqrt(np.sum((a-b)**2))

# %%
np.random.seed(seed)

# Generate data with Gaussian noise
x, y, y_err, true_params = cosine.generate(15,scale=0.01)
a, c, k, f = true_params

# Parameter names
model_params = ["a","c","k","f"]
design_vars = ["x"]

print("True parameter values:")
print(tuple(model_params), "=")
print((a,c,k,f))

# Design variable values
#design_vals = np.row_stack(np.broadcast(x,a,c))
design_vals = x

# Define uniform prior wrapper functions and samplers for the model parameters
param_prior = lambda sample: uniform.pdf(sample,-5.0,10.0)
param_sampler = lambda n_samples: np.random.uniform(-5.0,5.0,n_samples)

priors = [param_prior for param in model_params]
samplers = [param_sampler for param in model_params]

# Construct problem dict
problem_ext = {"model_type":"external",
               "setup":(lambda params: cosine.setup(modelpath,params)),
               "measure":cosine.read_output,
               "distance":distance,
               "model_params":model_params,
               "design_vars":design_vars,
               "input_data":design_vals,
               "output_data":y,
               "data_errors":y_err,
               "priors":priors,
               "samplers":samplers,
              }

problem_py = {"model_type":"python",
              "evaluate":cosine.evaluate_dict,
              "distance":distance,
              "model_params":model_params,
              "design_vars":design_vars,
              "input_data":design_vals,
              "output_data":y,
              "data_errors":y_err,
              "priors":priors,
              "samplers":samplers,
              }

try:
    shutil.rmtree("./ABCSubSim_output")
except FileNotFoundError:
    pass

os.makedirs("ABCSubSim_output")
os.chdir("ABCSubSim_output")

ABCSubSim_sampler = ABCSubSim.ABCSubSim(problem_py,logstep=20,logpath=logpath,nprocs=8,tol=0.5)
df,qoi = ABCSubSim_sampler.sample(n_samples)

os.chdir("..")

# Remove garbage
shutil.rmtree("./ABCSubSim_output")

print(df)
# Out:
# True parameter values:
# ('a', 'c', 'k', 'f') =
# (-3.084805496211077, 1.2210877103983186, -0.6227226099288554, 2.8535858371376923)
# Initializing...
# Running stage 1...
# Current tolerance value: 12.91943910345878
# Acceptance rate: 0.75
# Acceptance rate: 0.75
# Acceptance rate: 0.4375
# Acceptance rate: 0.5
# Acceptance rate: 0.5625
# Running stage 2...
# Current tolerance value: 9.897785589267071
# Acceptance rate: 0.1875
# Acceptance rate: 0.75
# Acceptance rate: 0.125
# Acceptance rate: 0.1875
# Acceptance rate: 0.375
# Running stage 3...
# Current tolerance value: 9.047467687666446
# Acceptance rate: 0.0625
# Acceptance rate: 0.0625
# Acceptance rate: 0.0625
# Acceptance rate: 0.0625
# Acceptance rate: 0.125
# Running stage 4...
# Current tolerance value: 6.205722707337038
# Acceptance rate: 0.1875
# Acceptance rate: 0.0
# Acceptance rate: 0.0
# Acceptance rate: 0.0
# Acceptance rate: 0.0
# Running stage 5...
# Current tolerance value: 6.205722707337038
# Acceptance rate: 0.75
# Acceptance rate: 0.75
# Acceptance rate: 0.3125
# Acceptance rate: 0.5625
# Acceptance rate: 0.4375
# Running stage 6...
# Current tolerance value: 5.225200367729577
# Acceptance rate: 0.25
# Acceptance rate: 0.3125
# Acceptance rate: 0.25
# Acceptance rate: 0.375
# Acceptance rate: 1.0
# Running stage 7...
# Current tolerance value: 4.199051396699344
# Acceptance rate: 1.0
# Acceptance rate: 0.125
# Acceptance rate: 0.1875
# Acceptance rate: 0.5
# Acceptance rate: 0.375
# Running stage 8...
# Current tolerance value: 3.7642637563488
# Acceptance rate: 0.9375
# Acceptance rate: 0.1875
# Acceptance rate: 1.0
# Acceptance rate: 0.75
# Acceptance rate: 0.0
# Running stage 9...
# Current tolerance value: 3.4391917211971608
# Acceptance rate: 0.125
# Acceptance rate: 0.0625
# Acceptance rate: 0.125
# Acceptance rate: 0.25
# Acceptance rate: 1.0
# Running stage 10...
# Current tolerance value: 3.0767554902015912
# Acceptance rate: 0.875
# Acceptance rate: 0.6875
# Acceptance rate: 0.875
# Acceptance rate: 0.75
# Acceptance rate: 0.25
# Running stage 11...
# Current tolerance value: 2.7563685293978244
# Acceptance rate: 0.9375
# Acceptance rate: 0.6875
# Acceptance rate: 0.25
# Acceptance rate: 0.75
# Acceptance rate: 0.6875
# Running stage 12...
# Current tolerance value: 2.1762161324886966
# Acceptance rate: 0.25
# Acceptance rate: 0.375
# Acceptance rate: 0.375
# Acceptance rate: 0.375
# Acceptance rate: 0.3125
# Running stage 13...
# Current tolerance value: 1.5749855059166735
# Acceptance rate: 0.125
# Acceptance rate: 0.375
# Acceptance rate: 0.4375
# Acceptance rate: 0.6875
# Acceptance rate: 0.5
# Running stage 14...
# Current tolerance value: 1.1280231095445208
# Acceptance rate: 0.1875
# Acceptance rate: 0.375
# Acceptance rate: 0.3125
# Acceptance rate: 0.5625
# Acceptance rate: 0.3125
# Running stage 15...
# Current tolerance value: 0.7496115839784874
# Acceptance rate: 0.0625
# Acceptance rate: 0.375
# Acceptance rate: 0.3125
# Acceptance rate: 0.625
# Acceptance rate: 0.125
# Running stage 16...
# Current tolerance value: 0.5619436667830289
# Acceptance rate: 0.0
# Acceptance rate: 0.625
# Acceptance rate: 0.25
# Acceptance rate: 0.5
# Acceptance rate: 0.3125
# Running stage 17...
# Current tolerance value: 0.367087489209221
# Acceptance rate: 0.75
# Acceptance rate: 0.6875
# Acceptance rate: 0.3125
# Acceptance rate: 0.375
# Acceptance rate: 0.125
# Minimum tolerance value reached
#            a         c         k         f  distance
# 0  -3.067505  1.267664  0.618841  3.366915  0.300798
# 1  -3.079796  1.339507  0.615415  3.362805  0.334101
# 2  -3.066399  1.299113  0.613228  3.365972  0.243974
# 3  -3.101095  1.310257  0.611333  3.365937  0.247447
# 4  -3.114996  1.278101  0.609984  3.373582  0.183017
# 5  -3.036952  1.204421  0.610134  3.371898  0.284910
# 6  -3.038920  1.255314  0.607504  3.371744  0.230989
# 7  -3.023652  1.270197  0.611513  3.363946  0.288710
# 8  -3.023652  1.270197  0.611513  3.363946  0.288710
# 9  -3.023652  1.270197  0.611513  3.363946  0.288710
# 10 -3.137601  1.314666  0.613372  3.390296  0.330827
# 11 -3.171691  1.294611  0.616784  3.384481  0.304542
# 12 -3.175721  1.294059  0.615994  3.376512  0.313801
# 13 -3.175721  1.294059  0.615994  3.376512  0.313801
# 14 -3.175721  1.294059  0.615994  3.376512  0.313801
# 15 -3.118051  1.281823  0.614873  3.380039  0.185232
# 16 -3.086884  1.310420  0.615860  3.375851  0.248711
# 17 -3.062645  1.269491  0.620878  3.370252  0.321992
# 18 -3.081692  1.284539  0.622070  3.376291  0.287249
# 19 -3.114018  1.345729  0.617033  3.373195  0.348680
# 20 -3.173368  1.205161  0.592536  3.344305  0.342790
# 21 -3.167199  1.245257  0.598155  3.333234  0.292037
# 22 -3.132868  1.308733  0.597291  3.335732  0.312753
# 23 -3.126719  1.270400  0.602950  3.334066  0.239967
# 24 -3.126719  1.270400  0.602950  3.334066  0.239967
# 25 -3.076205  1.268791  0.610084  3.350716  0.242299
# 26 -3.063892  1.327535  0.605705  3.352321  0.337763
# 27 -3.003967  1.287173  0.612633  3.360099  0.360732
# 28 -3.003967  1.287173  0.612633  3.360099  0.360732
# 29 -3.003967  1.287173  0.612633  3.360099  0.360732
# ..       ...       ...       ...       ...       ...
# 70 -3.167072  1.224175  0.612140  3.358861  0.367087
# 71 -3.167072  1.224175  0.612140  3.358861  0.367087
# 72 -3.098955  1.191093  0.595029  3.375295  0.316013
# 73 -3.098955  1.191093  0.595029  3.375295  0.316013
# 74 -3.114055  1.218592  0.604905  3.372601  0.175221
# 75 -3.144896  1.265088  0.585060  3.280541  0.342494
# 76 -3.144896  1.265088  0.585060  3.280541  0.342494
# 77 -3.144896  1.265088  0.585060  3.280541  0.342494
# 78 -3.144896  1.265088  0.585060  3.280541  0.342494
# 79 -3.144896  1.265088  0.585060  3.280541  0.342494
# 80 -3.144896  1.265088  0.585060  3.280541  0.342494
# 81 -3.144896  1.265088  0.585060  3.280541  0.342494
# 82 -3.144896  1.265088  0.585060  3.280541  0.342494
# 83 -3.144896  1.265088  0.585060  3.280541  0.342494
# 84 -3.110193  1.295871  0.607667  3.329343  0.300565
# 85 -3.116781  1.169658  0.605672  3.385866  0.260890
# 86 -3.116781  1.169658  0.605672  3.385866  0.260890
# 87 -3.116781  1.169658  0.605672  3.385866  0.260890
# 88 -3.116781  1.169658  0.605672  3.385866  0.260890
# 89 -3.116781  1.169658  0.605672  3.385866  0.260890
# 90 -3.045702  1.190613  0.610339  3.379133  0.272637
# 91 -3.045702  1.190613  0.610339  3.379133  0.272637
# 92 -3.045702  1.190613  0.610339  3.379133  0.272637
# 93 -3.051114  1.163240  0.629852  3.478098  0.198013
# 94 -3.051114  1.163240  0.629852  3.478098  0.198013
# 95 -3.113229  1.177119  0.618806  3.445889  0.210566
# 96 -3.113229  1.177119  0.618806  3.445889  0.210566
# 97 -3.113229  1.177119  0.618806  3.445889  0.210566
# 98 -3.113229  1.177119  0.618806  3.445889  0.210566
# 99 -3.113229  1.177119  0.618806  3.445889  0.210566
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Propagate input uncertainty to output

# %%
a,c,k,f = true_params

plt.figure(figsize=(20,10))
plt.grid(True)

# Data
plt.errorbar(x,y,yerr=y_err,label="Data")

# True values
interval = np.linspace(0,2*np.pi,1000)
y_true, _ = cosine.evaluate(interval,a,c,k,f)
#plt.plot(interval,y_true,label="True distribution")

# Highest likelihood
mde = np.argmin(df["distance"].values)
plt.plot(x,qoi[mde],label="Minimum Distance Sample")

# All distributions
#for n in range(qoi.shape[0]):
#    plt.plot(x,qoi[n])

# Mean QoI output
mean = np.mean(qoi,axis=0)
var = np.sum((qoi - mean[None,:])**2,axis=0) / (qoi.shape[0] - 1)
conf = 1.96 * np.sqrt(var / qoi.shape[0])

plt.errorbar(x,mean,yerr=conf,label="Mean QoI")

plt.legend()

plt.show()
